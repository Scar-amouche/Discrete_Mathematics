# %% [markdown]
# # 1. Proving Identities
#
# $\textbf{A.}$ A\B = A $\cap$ $B^{c}$ is $\textbf{TRUE}$<br>
#  if A\B={x | x $\in$ A $\land$ x $\notin$ B}<br>
#  if A$\cap$ $B^{c}$={x | x $\in$ A $\land$ x $\notin$ B}<br>
#  $\textbf{Example:}$<br>
#  A={1,2,3}<br>
#  B={3,4,5}<br>
#  A\B={1,2}<br>
#  A$\cap$ $B^{c}$={1,2}<br>
#
# $\textbf{B.}$ B = (B $\cap$ A) $\cup$ (B $\cap$ $A^{c}$) is $\textbf{TRUE}$ <br>
#  if B $\cap$ A={x | x $\in$ B $\land$ x $\in$ A} <br>
#  if B $\cap$ $A^{c}$={x | x $\in$ B $\land$ x $\notin$ A} and;<br>
#  if (B $\cap$ A) $\cup$ (B $\cap$ $A^{c}$) = {x | x $\in$ B $\land$ x $\in$ A}$\land${x | x $\in$ B $\land$ x $\notin$ A}<br>
#  $\textbf{Example:}$<br>
#  A={1,2,3}<br>
#  B={3,4,5}<br>
#  B $\cap$ A={3}<br>
#  B $\cap$ $A^{c}$={4,5}<br>
#  (B $\cap$ A) $\cup$ (B $\cap$ $A^{c}$)={3,4,5}<br>
#
# $\textbf{C.}$ B\A = B $\cap$ $A^{c}$is $\textbf{TRUE}$ <br>
#  if B\A={x | x $\in$ B $\land$ x $\notin$ A}<br>
#  if B $\cap$ $A^{c}$={x | x $\in$ B $\land$ x $\notin$ A}<br>
#  $\textbf{Example:}$<br>
#  A={1,2,3}<br>
#  B={3,4,5}<br>
#  B\A={4,5}<br>
#  B $\cap$ $A^{c}$={4,5}<br>
#
# $\textbf{D.}$ A $\cup$ B = A $\cup$ (B $\cap$ $A^{c}$)is $\textbf{TRUE}$ <br>
#  if A $\cup$ B = {x | x $\in$ A $\land$ x $\in$ B}<br>
#  if A $\cup$ (B $\cap$ $A^{c}$) = {x | x $\in$ B $\lor$ x $\in$ A}=$A^{c}$<br>
#  $\textbf{Example:}$<br>
#  A={1,2,3}<br>
#  B={3,4,5}<br>
#  A $\cup$ B = {1,2,3,4,5}<br>
#  B $\cap$ $A^{c}$ = {4,5}<br>
#  A $\cup$ (B $\cap$ $A^{c}$) = {1,2,3,4,5}<br>
#
# $\textbf{E.}$ $(\textbf{U}_{i=1}^{\infty}
# A_{i}^{c})^{c}$ = $\cap_{i=1}^{\infty}A_{i}$<br>
# $(\cup_{i=1}^{\infty} \textbf{A}_{i}^{c} = (\textbf{U})^{c} = \emptyset$<br>
# $\cap_{i=1}^{\infty}\textbf{A}_{i} = \emptyset$ the intersection of sets can be nothing, but $\cap_{i=1}^{\infty}\textbf{A}_{i} = \emptyset$
#
# $\textbf{F.}$ |A $\cup$ B| = |A| + |B| - |A $\cap$ B|is $\textbf{TRUE}$ <br>
#  It's the result of inclusion-exclusion principle<br>
#  $\textbf{Example:}$<br>
#  A={1,2,3}<br>
#  B={3,4,5}<br>
#  |A|=3<br>
#  |B|=3<br>
#  if we simply add them then there would be 1 repeating element<br>
#  |A $\cap$ B|=1<br>
#  |A $\cup$ B|=5<br>
#  |A $\cup$ B| = |A| + |B| - |A $\cap$ B|<br>
#        5      =  3  +  3  -       1<br>
#        5      =  5<br>

# %% [markdown]
# # 2. Sets and Subsets
# ---
# #### Use Latex Programming to show your solutions.
# - If A = {2,3,4,5}, and B = {$x \in \mathbb{N} | x \ is \ even$}. Is A $\subset$ B? Show a proof.<br>
# $\textbf False, A$ cannot be a subset of $\textbf B$, because $\textbf A$ contains $\textbf Odd Numbers$ It cannot Satisfy "$\textbf x$ is even."<br>
# $\textbf example:$<br>
#   A={2,3,4,5}<br>
#   B={2,4,6,8,...}<br>
#   {2,4} $\in$ A = {2,4} $\in$ B <br>
#   {3,5} $\not\subset$ B<br>
#   Therefore A $\not\subset$ B
#
# - Let sets $\textbf{A} = \{x|x \in \mathbb{Z}, 0 \leq x \leq 9\},
# \textbf{B} = \{ 2,4,6,8\},
# \ and \
# \textbf{C}  = \{ 1,3,5,7,9\}
# \ and \ \textbf{D}  = \{ 3,4,5\}$
# Find a set $\textbf{X}$ which will satisfy the following conditions:<br>
#     Let X={0,9} It will satisfy all conditions.
#     1. $\textbf{X} \ and \ \textbf{B}$ are disjoint.
#     -  ={0,9} $\cap$ {2,4,6,8}, they have no element in common
#     2. $\textbf{X} \subseteq \textbf{D}$ but $\textbf{X} \nsubseteq \textbf{B}$.
#     -  $\textbf{X} \subseteq \textbf{D}$={0,9}, $\textbf{X} \nsubseteq \textbf{B}$ is already proven on the first condition
#     3. $\textbf{X} \subseteq \textbf{A}$ but $\textbf{X} \not\subset \textbf{C}$.
#     -  $\textbf{X} \subseteq \textbf{A}$={0,9}, $\textbf{X} \not\subset \textbf{C}$={0,9} $\notin$ C

# %% [markdown]
# # 3. Set Operations
# ---
# #### Use this website https://learnpython.com/blog/set-operations-in-python/ to learn about set Operations in Python.
# ##### 1. First solve the problems manually, use Latex programming to show your manual solutions.
# ##### 2. Second, solve the problem using python. Show your codes for the pythonic solutions.
# ##### Hint: You know your solutions is right if your manual solution is equivalent to your pythonic solution.
#
# Given:<br>
# $\textbf{U} = \{1,2,3,4,5\}$<br>
# $\textbf{A} = \{1,2,3,4,5\}$<br>
# $\textbf{B} = \{4,5,6,7\}$<br>
# $\textbf{C} = \{5,6,7,8,9\}$<br>
# $\textbf{D} = \{1,3,5,7,9\}$<br>
# $\textbf{E} = \{2,4,6,8\}$<br>
# $\textbf{F} = \{1,5,9\}$<br>
# - $\textbf{C} \oplus \textbf{D}$
#     - $\textbf{C} \oplus \textbf{D}$ = (C\D)$\cup$(D\C)
#     - C\D = {6,8}
#     - D\c = {1,3}
#     - Therefore $\textbf{C} \oplus \textbf{D}$ = {1,3,6,8}
# - $\textbf{A} \backslash \textbf{B}$
#     - A\B = {1,2,3,4,5} $\backslash$ {4,5,6,7}
#     - A\B = {1,2,3}
# - $\textbf{B} \backslash \textbf{A}$
#     - B\A = {4,5,6,7} $\backslash$ {1,2,3,4,5}
#     - B\A = {6,7}
# - $\textbf{E} \oplus \textbf{F}$
#     - $\textbf{E} \oplus \textbf{F}$ = (E\F)$\cup$(F\E)
#     - E\F = {2,4,6,8}
#     - F\E = {1,5,9}
#     - Therefore,  $\textbf{E} \oplus \textbf{F}$ = {1,2,4,5,6,8,9}

# %%
U = {1,2,3,4,5}
A = {1,2,3,4,5}
B = {4,5,6,7}
C = {5,6,7,8,9}
D = {1,3,5,7,9}
E = {2,4,6,8}
F = {1,5,9}
print(f"𝐂⊕𝐃 = {C ^ D}")
print(f"𝐀∖𝐁 = {A - B}")
print(f"𝐁∖𝐀 = {B - A}")
print(f"𝐄⊕𝐅 = {E ^ F}")
# Out:
# 𝐂⊕𝐃 = {1, 3, 6, 8}
# 𝐀∖𝐁 = {1, 2, 3}
# 𝐁∖𝐀 = {6, 7}
# 𝐄⊕𝐅 = {1, 2, 4, 5, 6, 8, 9}

# %% [markdown]
# # 4. Finite Sets and The Counting Principles
# ---
#
# In a Survey of 120 People, it was found that:
# - 65 read Newsweek Magazine
# - 45 read Times Magazine
# - 42 read Fortune Magazine
# - 20 read Both Newsweek and Time
# - 25 read both Newsweek and Fortune
# - 15 read both Time and Fortune
# - 8 read all three magazines
# With these information do the following:<br>
# 1. Draw the venn diagram using python.
# 2. Find the number of people who read at $\textbf{"least one"}$ of the three magazines.
# 3. Find the number of people who read exactly one magazine.
# <br>
# <br>
# In a survey of 25 new cars being sold at a local auto dealer was conducted to see which of the three popular options: air-conditioning, denoted as A; radio, denoted as R; and power windows, denoted as W were installed. The survey found that:
# - 15 had A. HINT: The condition said $\textbf{"had an A"}$  <font color='red'>$\textbf{ AND NOT}$ <font color='black'>$\textbf{"had an A only"}$
# - 12 had R. HINT: The condition said $\textbf{"had a R"}$  <font color='red'>$\textbf{ AND NOT}$ <font color='black'>$\textbf{"had a R only"}$
# - 11 had W. HINT: The condition said $\textbf{"had a W"}$  <font color='red'>$\textbf{ AND NOT}$ <font color='black'>$\textbf{"had a W only"}$
# - 5 had A and W.
# - 9 had A and R.
# - 4 had R and W.
# - Only 3 hace the three options.
# With these information do the following:<br>
# 1. Draw the venn diagram using python.<br>
# 2. Find the number of cars with W only.<br>
# 3. Find the number of cars with A only.<br>
# 4. Find the number of cars with R only.<br>
# 5. Find the number of cars with both R and W but not A.<br>
# 6. Find the number of cars with both A and R but not W.<br>
# 7. Find the number of cars with only one of the options.<br>
# 8. Find the number of cars with at least one option.<br>
# 9. Find the number of cars with none of the Options.<br>

# %% [markdown]
# First Problem
# Given:<br>
# -120 people were surveyed <br>
# -65 read the newsweek magazine (NM) <br>
# -45 read the times magazine (TM) <br>
# -42 read the fortune magazine (FM) <br>
# -20 read the newsweek and times magazine (NTM) <br>
# -25 read the newsweek and fortune magazine (NFM) <br>
# -15 read the time and fortune magazine (TFM) <br>
# -8 read all three (NFTM) <br>

# %%
import matplotlib.pyplot as plt
NM = 65  # Number of people who read Newsweek Magazine
TM = 45  # Number of people who read Times Magazine
FM = 42  # Number of people who read Fortune Magazine
NTM = 20  # Number of people who read both Newsweek and Time
NFM = 25  # Number of people who read both Newsweek and Fortune
TFM = 15  # Number of people who read both Time and Fortune
NFTM = 8  # Number of people who read all three magazines

# Creating the Venn diagram
venn3(subsets=(NM - NTM - NFM + NFTM,
               TM - NTM - TFM + NFTM,
               NTM - NFTM,
               FM - NFM - TFM + NFTM,
               NFM - NFTM,
               TFM - NFTM,
               NFTM),
      set_labels=('Newsweek', 'Times', 'Fortune'))

plt.title("Magazine Readers Diagram")
plt.show()

#finding the people who read at least one of the three magazine
peeps_who_read_atlis_wan =NM + TM + FM - (NTM + NFM + TFM) + NFTM 

#finding the number of people who read only one magazine
peeps_who_read_only_wan = (NM - NTM - NFM + NFTM) + (TM - NTM - TFM + NFTM) + (FM - NFM - TFM + NFTM)

print("people who read at least one of the three magazine:", peeps_who_read_atlis_wan )
print("people who read only one magazine:", peeps_who_read_only_wan)
# Out:
# people who read at least one of the three magazine: 100
# people who read only one magazine: 56

# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn3

# Given data
TC = 25
AC = 15  # Number of cars with AC (air-conditioning)
R = 12  # Number of cars with R (radio)
PW = 11  # Number of cars with PW (power windows)
ACPW = 5  # Number of cars with both AC and PW
ACR = 9  # Number of cars with both A and R
RPW = 4  # Number of cars with both R and W
ACRPW = 3  # Number of cars with all three options

# Creating the Venn diagram
venn_diagram = venn3(subsets=(AC - ACPW - ACR + ACRPW,
                              R - ACR - RPW + ACRPW,
                              ACR - ACRPW,
                              PW - ACPW - RPW + ACRPW,
                              RPW - ACRPW,
                              ACPW - ACRPW,
                              ACRPW),
                     set_labels=('Air Conditioned', 'Radio', 'Power Windows'))

# Displaying the Venn diagram
plt.title("Car Options Venn Diagram")
plt.show()

# Calculate the requested numbers

# Number of cars with W only
PW = PW - RPW - ACPW + ACRPW

# Number of cars with A only
AC = AC - ACPW - ACR + ACRPW

# Number of cars with R only
R = R - ACR - RPW + ACRPW

# Number of cars with both R and W but not A
RPW_not_A = RPW - ACRPW

# Number of cars with both A and R but not W
ACR_not_W = ACR - ACRPW

# Number of cars with only one of the options
goodcar = AC + R + PW 

# Number of cars with at least one option
kindamidcar = TC 

# Number of cars with none of the options
poorcar = TC - ACPW - ACR - RPW 

# Print the results
print("cars with W only:", PW)
print("cars with A only:", AC)
print("cars with R only:", R)
print("cars with both R and W but not A:", RPW_not_A)
print("cars with both A and R but not W:", ACR_not_W)
print("cars with only one of the options:", goodcar)
print("cars with at least one option:", kindamidcar)
print("cars with none of the options:", poorcar)
# Out:
# cars with W only: 5
# cars with A only: 4
# cars with R only: 2
# cars with both R and W but not A: 1
# cars with both A and R but not W: 6
# cars with only one of the options: 11
# cars with at least one option: 25
# cars with none of the options: 7
